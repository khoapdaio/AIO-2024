# %%
# !gdown "1OFgBOb4B1j32uK26vf5urkp8rqVmD_Wf"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1OFgBOb4B1j32uK26vf5urkp8rqVmD_Wf
# To: O:\Git\AIO-2024\src\module5\week1\titanic.zip
#
#   0%|          | 0.00/7.00k [00:00<?, ?B/s]
# 100%|##########| 7.00k/7.00k [00:00<?, ?B/s]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
dataset_path = 'titanic_modified_dataset.csv'
df = pd.read_csv(
	dataset_path,
	index_col = 'PassengerId'
)
df.head()
# Out:
#              Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Title  \
# PassengerId
# 1                 3    0  22.0      1      0   7.2500         0      0
# 2                 1    1  38.0      1      0  71.2833         1      1
# 3                 3    1  26.0      0      0   7.9250         0      2
# 4                 1    1  35.0      1      0  53.1000         0      1
# 5                 3    0  35.0      0      0   8.0500         0      0
#
#              Survived
# PassengerId
# 1                   0
# 2                   1
# 3                   1
# 4                   1
# 5                   0

# %%
dataset_arr = df.to_numpy().astype(np.float64)
X, y = dataset_arr[:, : -1], dataset_arr[:, -1]

# %%
intercept = np.ones((
	X.shape[0], 1)
)
X_b = np.concatenate(
	(intercept, X),
	axis = 1
)

# %%
val_size = 0.2
test_size = 0.125
random_state = 2
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(
	X_b, y,
	test_size = val_size,
	random_state = random_state,
	shuffle = is_shuffle
)

X_train, X_test, y_train, y_test = train_test_split(
	X_train, y_train,
	test_size = test_size,
	random_state = random_state,
	shuffle = is_shuffle
)

# %%
normalizer = StandardScaler()
X_train[:, 1:] = normalizer.fit_transform(X_train[:, 1:])
X_val[:, 1:] = normalizer.transform(X_val[:, 1:])
X_test[:, 1:] = normalizer.transform(X_test[:, 1:])

# %%
def sigmoid(z):
	return 1 / (1 + np.exp(-z))

# %%
def predict(X, theta):
	dot_product = np.dot(X, theta)
	y_hat = sigmoid(dot_product)

	return y_hat

# %%
def compute_loss(y_hat, y):
	y_hat = np.clip(
		y_hat, 1e-7, 1 - 1e-7
	)
	return (-y * np.log(y_hat) - (1 - y) * np.log(1 - y_hat)).mean()

# %%
def compute_gradient(X, y, y_hat):
	return np.dot(X.T, (y_hat - y)) / y.size

# %%
def update_theta(theta, gradient, lr):
	return theta - lr * gradient

# %%
def compute_accuracy(X, y, theta):
	y_hat = predict(X, theta).round()
	acc = (y_hat == y).mean()

	return acc

# %%
lr = 0.01
epochs = 100
batch_size = 16

np.random.seed(random_state)
theta = np.random.uniform(
	size = X_train.shape[1]
)

# %%
train_accs = []
train_losses = []
val_accs = []
val_losses = []

for epoch in range(epochs):
	train_batch_losses = []
	train_batch_accs = []
	val_batch_losses = []
	val_batch_accs = []

	for i in range(0, X_train.shape[0], batch_size):
		X_i = X_train[i:i + batch_size]
		y_i = y_train[i:i + batch_size]

		y_hat = predict(X_i, theta)

		train_loss = compute_loss(y_hat, y_i)

		gradient = compute_gradient(X_i, y_i, y_hat)

		theta = update_theta(theta, gradient, lr)

		train_batch_losses.append(train_loss)

		train_acc = compute_accuracy(X_train, y_train, theta)
		train_batch_accs.append(train_acc)

		y_val_hat = predict(X_val, theta)
		val_loss = compute_loss(y_val_hat, y_val)
		val_batch_losses.append(val_loss)

		val_acc = compute_accuracy(X_val, y_val, theta)
		val_batch_accs.append(val_acc)

	train_batch_loss = sum(train_batch_losses) / len(
		train_batch_losses)
	val_batch_loss = sum(val_batch_losses) / len(val_batch_losses)
	train_batch_acc = sum(train_batch_accs) / len(train_batch_accs)
	val_batch_acc = sum(val_batch_accs) / len(val_batch_accs)

	train_losses.append(train_batch_loss)
	val_losses.append(val_batch_loss)
	train_accs.append(train_batch_acc)
	val_accs.append(val_batch_acc)

	print(f'\nEPOCH{epoch + 1}:\tTraining loss: {train_batch_loss: .3f}\tValidation loss: {val_batch_loss: .3f}')
# Out:
# EPOCH1:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH2:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH3:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH4:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH5:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH6:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH7:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH8:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH9:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH10:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH11:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH12:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH13:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH14:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH15:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH16:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH17:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH18:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH19:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH20:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH21:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH22:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH23:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH24:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH25:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH26:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH27:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH28:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH29:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH30:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH31:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH32:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH33:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH34:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH35:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH36:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH37:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH38:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH39:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH40:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH41:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH42:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH43:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH44:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH45:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH46:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH47:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH48:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH49:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH50:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH51:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH52:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH53:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH54:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH55:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH56:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH57:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH58:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH59:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH60:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH61:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH62:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH63:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH64:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH65:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH66:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH67:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH68:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH69:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH70:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH71:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH72:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH73:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH74:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH75:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH76:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH77:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH78:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH79:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH80:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH81:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH82:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH83:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH84:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH85:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH86:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH87:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH88:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH89:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH90:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH91:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH92:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH93:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH94:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH95:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH96:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH97:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH98:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH99:	Training loss:  0.411	Validation loss:  0.525
#
# EPOCH100:	Training loss:  0.411	Validation loss:  0.525

# %%
fig, ax = plt.subplots(2, 2, figsize = (12, 10))
ax[0, 0].plot(train_losses)
ax[0, 0].set(xlabel = 'Epoch', ylabel = 'Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_losses, 'orange')
ax[0, 1].set(xlabel = 'Epoch', ylabel = 'Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_accs)
ax[1, 0].set(xlabel = 'Epoch', ylabel = 'Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_accs, 'orange')
ax[1, 1].set(xlabel = 'Epoch', ylabel = 'Accuracy')
ax[1, 1].set_title('Validation Accuracy')

plt.show()

# %%
val_set_acc = compute_accuracy(X_val, y_val, theta)
test_set_acc = compute_accuracy(X_test, y_test, theta)
print('Evaluation on validation and test set :')
print(f'Accuracy : {val_set_acc}')
print(f'Accuracy : {test_set_acc}')
# Out:
# Evaluation on validation and test set :
# Accuracy : 0.776536312849162
# Accuracy : 0.7865168539325843

# %%
# !gdown 1u_lWZPAVIdWG2gsi5myYhdtMoJ3MP0_j
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1u_lWZPAVIdWG2gsi5myYhdtMoJ3MP0_j
# To: O:\Git\AIO-2024\src\module5\week1\twitter_sentiment_analysis_2cls_dataset.zip
#
#   0%|          | 0.00/471k [00:00<?, ?B/s]
# 100%|##########| 471k/471k [00:00<00:00, 1.68MB/s]
# 100%|##########| 471k/471k [00:00<00:00, 1.68MB/s]

# %%
import pandas as pd
import numpy as np
import re
import nltk
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from nltk.tokenize import TweetTokenizer
from collections import defaultdict

# %%
dataset_path = 'sentiment_analysis.csv'
df = pd.read_csv(
	dataset_path,
	index_col = 'id'
)
df.head()
# Out:
#     label                                              tweet
# id
# 1       0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 2       0  Finally a transparant silicon case ^^ Thanks t...
# 3       0  We love this! Would you go? #talk #makememorie...
# 4       0  I'm wired I know I'm George I was made that wa...
# 5       1  What amazing service! Apple won't even talk to...

# %%
def text_normalize(text):
	# Retweet old acronym "RT" removal
	text = re.sub(r'^RT [\s]+', '', text)

	# Hyperlinks removal
	text = re.sub(r'https?:\/\/.*[\ r\n]*', '', text)

	# Hashtags removal
	text = re.sub(r'#', '', text)

	# Punctuation removal
	text = re.sub(r'[^\ w\s]', '', text)

	# Tokenization
	tokenizer = TweetTokenizer(
		preserve_case = False,
		strip_handles = True,
		reduce_len = True
	)
	text_tokens = tokenizer.tokenize(text)
	return text_tokens

# %%
def get_freqs(df):
	freqs = defaultdict(lambda: 0)
	for idx, row in df.iterrows():
		tweet = row['tweet']
		label = row['label']

		tokens = text_normalize(tweet)
		for token in tokens:
			pair = (token, label)
			freqs[pair] += 1

	return freqs

# %%
def get_feature(text, freqs):
	tokens = text_normalize(text)

	X = np.zeros(3)
	X[0] = 1

	for token in tokens:
		X[1] += freqs[(token, 0)]
		X[2] += freqs[(token, 1)]

	return X

# %%
X = []
y = []

freqs = get_freqs(df)
for idx, row in df.iterrows():
	tweet = row['tweet']
	label = row['label']
	X_i = get_feature(tweet, freqs)
	X.append(X_i)
	y.append(label)

X = np.array(X)
y = np.array(y)

# %%
val_size = 0.2
test_size = 0.125
random_state = 2
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(
	X, y,
	test_size = val_size,
	random_state = random_state,
	shuffle = is_shuffle
)

X_train, X_test, y_train, y_test = train_test_split(
	X_train, y_train,
	test_size = test_size,
	random_state = random_state,
	shuffle = is_shuffle
)

# %%
normalizer = StandardScaler()
X_train[:, 1:] = normalizer.fit_transform(X_train[:, 1:])
X_val[:, 1:] = normalizer.transform(X_val[:, 1:])
X_test[:, 1:] = normalizer.transform(X_test[:, 1:])

# %%
def sigmoid(z):
	return 1 / (1 + np.exp(-z))


def compute_loss(y_hat, y):
	y_hat = np.clip(y_hat, 1e-7, 1 - 1e-7)
	return (-y * np.log(y_hat) - (1 - y) * np.log(1 - y_hat)).mean()


def predict(X, theta):
	dot_product = np.dot(X, theta)
	y_hat = sigmoid(dot_product)
	return y_hat


def compute_gradient(X, y, y_hat):
	return np.dot(X.T, (y_hat - y)) / y.size


def update_theta(theta, gradient, lr):
	return theta - lr * gradient


def compute_accuracy(X, y, theta):
	y_hat = predict(X, theta).round()
	acc = (y_hat == y).mean()

	return acc

# %%
lr = 0.01
epochs = 200
batch_size = 128

np.random.seed(random_state)
theta = np.random.uniform(
	size = X_train.shape[1]
)

# %%
for epoch in range(epochs):
	train_batch_losses = []
	train_batch_accs = []
	val_batch_losses = []
	val_batch_accs = []

	for i in range(0, X_train.shape[0], batch_size):
		X_i = X_train[i:i + batch_size]
		y_i = y_train[i:i + batch_size]

		y_hat = predict(X_i, theta)

		train_loss = compute_loss(y_hat, y_i)

		gradient = compute_gradient(X_i, y_i, y_hat)

		theta = update_theta(theta, gradient, lr)

		train_batch_losses.append(train_loss)

		train_acc = compute_accuracy(X_train, y_train, theta)
		train_batch_accs.append(train_acc)

		y_val_hat = predict(X_val, theta)
		val_loss = compute_loss(y_val_hat, y_val)
		val_batch_losses.append(val_loss)

		val_acc = compute_accuracy(X_val, y_val, theta)
		val_batch_accs.append(val_acc)

	train_batch_loss = sum(train_batch_losses) / len(
		train_batch_losses)
	val_batch_loss = sum(val_batch_losses) / len(val_batch_losses)
	train_batch_acc = sum(train_batch_accs) / len(train_batch_accs)
	val_batch_acc = sum(val_batch_accs) / len(val_batch_accs)

	train_losses.append(train_batch_loss)
	val_losses.append(val_batch_loss)
	train_accs.append(train_batch_acc)
	val_accs.append(val_batch_acc)

	print(f'\nEPOCH{epoch + 1}:\tTraining loss: {train_batch_loss: .3f}\tValidation loss: {val_batch_loss: .3f}')
# Out:
# EPOCH1:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH2:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH3:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH4:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH5:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH6:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH7:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH8:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH9:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH10:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH11:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH12:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH13:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH14:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH15:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH16:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH17:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH18:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH19:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH20:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH21:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH22:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH23:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH24:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH25:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH26:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH27:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH28:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH29:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH30:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH31:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH32:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH33:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH34:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH35:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH36:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH37:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH38:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH39:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH40:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH41:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH42:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH43:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH44:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH45:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH46:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH47:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH48:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH49:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH50:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH51:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH52:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH53:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH54:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH55:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH56:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH57:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH58:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH59:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH60:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH61:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH62:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH63:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH64:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH65:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH66:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH67:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH68:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH69:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH70:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH71:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH72:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH73:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH74:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH75:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH76:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH77:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH78:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH79:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH80:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH81:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH82:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH83:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH84:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH85:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH86:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH87:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH88:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH89:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH90:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH91:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH92:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH93:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH94:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH95:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH96:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH97:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH98:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH99:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH100:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH101:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH102:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH103:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH104:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH105:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH106:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH107:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH108:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH109:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH110:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH111:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH112:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH113:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH114:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH115:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH116:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH117:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH118:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH119:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH120:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH121:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH122:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH123:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH124:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH125:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH126:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH127:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH128:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH129:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH130:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH131:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH132:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH133:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH134:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH135:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH136:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH137:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH138:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH139:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH140:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH141:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH142:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH143:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH144:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH145:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH146:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH147:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH148:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH149:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH150:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH151:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH152:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH153:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH154:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH155:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH156:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH157:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH158:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH159:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH160:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH161:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH162:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH163:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH164:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH165:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH166:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH167:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH168:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH169:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH170:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH171:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH172:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH173:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH174:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH175:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH176:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH177:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH178:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH179:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH180:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH181:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH182:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH183:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH184:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH185:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH186:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH187:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH188:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH189:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH190:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH191:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH192:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH193:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH194:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH195:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH196:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH197:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH198:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH199:	Training loss:  0.570	Validation loss:  0.573
#
# EPOCH200:	Training loss:  0.570	Validation loss:  0.573

# %%
fig, ax = plt.subplots(2, 2, figsize = (12, 10))
ax[0, 0].plot(train_losses)
ax[0, 0].set(xlabel = 'Epoch', ylabel = 'Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_losses, 'orange')
ax[0, 1].set(xlabel = 'Epoch', ylabel = 'Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_accs)
ax[1, 0].set(xlabel = 'Epoch', ylabel = 'Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_accs, 'orange')
ax[1, 1].set(xlabel = 'Epoch', ylabel = 'Accuracy')
ax[1, 1].set_title('Validation Accuracy')

plt.show()

# %%
val_set_acc = compute_accuracy (X_val , y_val , theta )
test_set_acc = compute_accuracy ( X_test , y_test , theta )
print ('Evaluation on validation and test set :')
print (f'Accuracy : { val_set_acc }')
print (f'Accuracy : { test_set_acc }')
