# %% [markdown]
# ## Exercise: Credit Card Fraud Detection

# %% [markdown]
# ### 1. Tải bộ dữ liệu

# %%
# !gdown --id 1kU64ckjel-CpAH352bwU5hWMFT_caZxZ
# Out:
# C:\Users\Khoaddow\AppData\Local\Programs\Python\Python312\Lib\site-packages\gdown\__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1kU64ckjel-CpAH352bwU5hWMFT_caZxZ
# From (redirected): https://drive.google.com/uc?id=1kU64ckjel-CpAH352bwU5hWMFT_caZxZ&confirm=t&uuid=32f7ad8b-575d-4fa8-886e-b6f3862972e9
# To: O:\Git\AIO-2024\src\module5\week2\card_fraud_detection.zip
#
#   0%|          | 0.00/69.2M [00:00<?, ?B/s]
#   1%|          | 524k/69.2M [00:00<01:01, 1.12MB/s]
#   2%|1         | 1.05M/69.2M [00:00<00:39, 1.73MB/s]
#   2%|2         | 1.57M/69.2M [00:00<00:33, 2.05MB/s]
#   3%|3         | 2.10M/69.2M [00:01<00:27, 2.40MB/s]
#   4%|3         | 2.62M/69.2M [00:01<00:23, 2.79MB/s]
#   5%|4         | 3.15M/69.2M [00:01<00:22, 2.97MB/s]
#   5%|5         | 3.67M/69.2M [00:01<00:21, 3.08MB/s]
#   6%|6         | 4.19M/69.2M [00:01<00:18, 3.42MB/s]
#   7%|6         | 4.72M/69.2M [00:01<00:18, 3.48MB/s]
#   8%|7         | 5.24M/69.2M [00:01<00:17, 3.63MB/s]
#   8%|8         | 5.77M/69.2M [00:01<00:16, 3.83MB/s]
#   9%|9         | 6.29M/69.2M [00:02<00:15, 3.94MB/s]
#  10%|9         | 6.82M/69.2M [00:02<00:15, 4.06MB/s]
#  11%|#         | 7.34M/69.2M [00:02<00:15, 4.00MB/s]
#  11%|#1        | 7.86M/69.2M [00:02<00:15, 3.93MB/s]
#  12%|#2        | 8.39M/69.2M [00:02<00:17, 3.54MB/s]
#  13%|#2        | 8.91M/69.2M [00:02<00:17, 3.44MB/s]
#  14%|#3        | 9.44M/69.2M [00:03<00:19, 3.03MB/s]
#  14%|#4        | 9.96M/69.2M [00:03<00:19, 3.06MB/s]
#  15%|#5        | 10.5M/69.2M [00:03<00:18, 3.17MB/s]
#  16%|#5        | 11.0M/69.2M [00:03<00:17, 3.34MB/s]
#  17%|#6        | 11.5M/69.2M [00:03<00:17, 3.33MB/s]
#  17%|#7        | 12.1M/69.2M [00:03<00:15, 3.59MB/s]
#  18%|#8        | 12.6M/69.2M [00:03<00:15, 3.60MB/s]
#  19%|#8        | 13.1M/69.2M [00:04<00:18, 2.96MB/s]
#  20%|#9        | 13.6M/69.2M [00:04<00:17, 3.12MB/s]
#  20%|##        | 14.2M/69.2M [00:04<00:15, 3.46MB/s]
#  21%|##1       | 14.7M/69.2M [00:04<00:16, 3.34MB/s]
#  22%|##1       | 15.2M/69.2M [00:04<00:15, 3.39MB/s]
#  23%|##2       | 15.7M/69.2M [00:04<00:15, 3.44MB/s]
#  24%|##3       | 16.3M/69.2M [00:05<00:14, 3.59MB/s]
#  84%|########4 | 58.2M/69.2M [00:17<00:03, 3.10MB/s]
#  85%|########4 | 58.7M/69.2M [00:17<00:03, 3.24MB/s]
#  86%|########5 | 59.2M/69.2M [00:17<00:03, 3.27MB/s]
#  86%|########6 | 59.8M/69.2M [00:17<00:02, 3.30MB/s]
#  87%|########7 | 60.3M/69.2M [00:17<00:02, 3.25MB/s]
#  88%|########7 | 60.8M/69.2M [00:17<00:02, 3.40MB/s]
#  89%|########8 | 61.3M/69.2M [00:18<00:02, 3.32MB/s]
#  89%|########9 | 61.9M/69.2M [00:18<00:02, 3.45MB/s]
#  90%|######### | 62.4M/69.2M [00:18<00:01, 3.43MB/s]
#  91%|######### | 62.9M/69.2M [00:18<00:01, 3.59MB/s]
#  92%|#########1| 63.4M/69.2M [00:18<00:01, 2.92MB/s]
#  92%|#########2| 64.0M/69.2M [00:18<00:01, 3.15MB/s]
#  93%|#########3| 64.5M/69.2M [00:19<00:01, 2.97MB/s]
#  94%|#########4| 65.0M/69.2M [00:19<00:01, 3.32MB/s]
#  95%|#########4| 65.5M/69.2M [00:19<00:01, 3.56MB/s]
#  96%|#########5| 66.1M/69.2M [00:19<00:00, 3.62MB/s]
#  96%|#########6| 66.6M/69.2M [00:19<00:00, 3.41MB/s]
#  97%|#########7| 67.1M/69.2M [00:19<00:00, 3.50MB/s]
#  98%|#########7| 67.6M/69.2M [00:19<00:00, 3.63MB/s]
#  99%|#########8| 68.2M/69.2M [00:20<00:00, 3.64MB/s]
#  99%|#########9| 68.7M/69.2M [00:20<00:00, 3.25MB/s]
# 100%|##########| 69.2M/69.2M [00:20<00:00, 3.45MB/s]
# 100%|##########| 69.2M/69.2M [00:20<00:00, 3.40MB/s]

# %%
# !py unzip 'card_fraud_detection.zip'
# Out:
# C:\Users\Khoaddow\AppData\Local\Programs\Python\Python312\python.exe: can't open file 'O:\\Git\\AIO-2024\\src\\module5\\week2\\unzip': [Errno 2] No such file or directory

# %% [markdown]
# ### 2. Import Thư viện

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### 3. Đọc dữ liệu

# %%
dataset_path = 'creditcard.csv'
df = pd.read_csv(
	dataset_path
)
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# ### 4. Tách biến X,y

# %%
dataset_arr = df.to_numpy()
X, y = dataset_arr[:, : -1].astype(np.float64), dataset_arr[:, -1].astype(np.uint8)

# %% [markdown]
# ### 5. Thêm bias vào X

# %%
intercept = np.ones((
	X.shape[0], 1)
)
X_b = np.concatenate(
	(intercept, X),
	axis = 1
)

# %% [markdown]
# ### 6. One-hot encoding label:

# %%
n_classes = np.unique(y, axis = 0).shape[0]
n_samples = y.shape[0]
y_encoded = np.array(
	[np.zeros(n_classes) for _ in range(n_samples)]
)
y_encoded[np.arange(n_samples), y] = 1

# %% [markdown]
# ### 7. Chia tập train, val, test:

# %%
val_size = 0.2
test_size = 0.125
random_state = 2
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(
	X_b, y_encoded,
	test_size = val_size,
	random_state = random_state,
	shuffle = is_shuffle
)

X_train, X_test, y_train, y_test = train_test_split(
	X_train, y_train,
	test_size = test_size,
	random_state = random_state,
	shuffle = is_shuffle
)

# %% [markdown]
# ### 8. Chuẩn hóa dữ liệu:

# %%
normalizer = StandardScaler()
X_train[:, 1:] = normalizer.fit_transform(X_train[:, 1:])
X_val[:, 1:] = normalizer.transform(X_val[:, 1:])
X_test[:, 1:] = normalizer.transform(X_test[:, 1:])

# %% [markdown]
# ### 9. Cài đặt các hàm quan trọng:

# %% [markdown]
# #### Hàm Softmax

# %%
def softmax(z):
	exp_z = np.exp(z)

	return exp_z / exp_z.sum(axis = 1)[:, None]

# %% [markdown]
# #### Hàm dự đoán:

# %%
def predict(X, theta):
	z = np.dot(X, theta)
	y_hat = softmax(z)

	return y_hat

# %% [markdown]
# #### Hàm tính loss:

# %%
def compute_loss(y_hat, y):
	n = y.size

	return (-1 / n) * np.sum(y * np.log(y_hat))

# %% [markdown]
# #### Hàm tính gradient:

# %%
def compute_gradient(X, y, y_hat):
	n = y.size

	return np.dot(X.T, (y_hat - y)) / n

# %% [markdown]
# #### Hàm cập nhật trọng số:

# %%
def update_theta(theta, gradient, lr):
	return theta - lr * gradient

# %% [markdown]
# #### Hàm tính độ chính xác:

# %%
def compute_accuracy(X, y, theta):
	y_hat = predict(X, theta)
	acc = (np.argmax(y_hat, axis = 1) == np.argmax(y, axis = 1)).mean()

	return acc

# %% [markdown]
# ### 10. Khai báo các siêu tham số và khởi tạo weights:

# %%
lr = 0.01
epochs = 30
batch_size = 1024
n_features = X_train.shape[1]

np.random.seed(random_state)
theta = np.random.uniform(
	size = (n_features, n_classes)
)

# %% [markdown]
# ### 11. Huấn luyện mô hình:

# %%
train_accs = []
train_losses = []
val_accs = []
val_losses = []

for epoch in range(epochs):
	train_batch_losses = []
	train_batch_accs = []
	val_batch_losses = []
	val_batch_accs = []

	for i in range(0, X_train.shape[0], batch_size):
		X_i = X_train[i:i + batch_size]
		y_i = y_train[i:i + batch_size]

		y_hat = predict(X_i, theta)
		train_loss = compute_loss(y_hat, y_i)

		gradient = compute_gradient(X_i, y_i, y_hat)

		theta = update_theta(theta, gradient, lr)

		train_batch_losses.append(train_loss)

		train_acc = compute_accuracy(X_train, y_train, theta)
		train_batch_accs.append(train_acc)

		y_val_hat = predict(X_val, theta)
		val_loss = compute_loss(y_val_hat, y_val)
		val_batch_losses.append(val_loss)

		val_acc = compute_accuracy(X_val, y_val, theta)
		val_batch_accs.append(val_acc)

	train_batch_loss = sum(train_batch_losses) / len(
		train_batch_losses)
	val_batch_loss = sum(val_batch_losses) / len(val_batch_losses)
	train_batch_acc = sum(train_batch_accs) / len(train_batch_accs)
	val_batch_acc = sum(val_batch_accs) / len(val_batch_accs)

	train_losses.append(train_batch_loss)
	val_losses.append(val_batch_loss)
	train_accs.append(train_batch_acc)
	val_accs.append(val_batch_acc)

	print(f'\nEPOCH {epoch + 1}:\tTraining loss : {train_batch_loss:.3f}\tValidation loss : {val_batch_loss:.3f}')
# Out:
# EPOCH 1:	Training loss : 0.176	Validation loss : 0.174
#
# EPOCH 2:	Training loss : 0.115	Validation loss : 0.113
#
# EPOCH 3:	Training loss : 0.081	Validation loss : 0.080
#
# EPOCH 4:	Training loss : 0.062	Validation loss : 0.061
#
# EPOCH 5:	Training loss : 0.049	Validation loss : 0.049
#
# EPOCH 6:	Training loss : 0.041	Validation loss : 0.041
#
# EPOCH 7:	Training loss : 0.035	Validation loss : 0.035
#
# EPOCH 8:	Training loss : 0.031	Validation loss : 0.031
#
# EPOCH 9:	Training loss : 0.028	Validation loss : 0.027
#
# EPOCH 10:	Training loss : 0.025	Validation loss : 0.025
#
# EPOCH 11:	Training loss : 0.023	Validation loss : 0.023
#
# EPOCH 12:	Training loss : 0.021	Validation loss : 0.021
#
# EPOCH 13:	Training loss : 0.020	Validation loss : 0.020
#
# EPOCH 14:	Training loss : 0.019	Validation loss : 0.018
#
# EPOCH 15:	Training loss : 0.017	Validation loss : 0.017
#
# EPOCH 16:	Training loss : 0.017	Validation loss : 0.016
#
# EPOCH 17:	Training loss : 0.016	Validation loss : 0.015
#
# EPOCH 18:	Training loss : 0.015	Validation loss : 0.015
#
# EPOCH 19:	Training loss : 0.014	Validation loss : 0.014
#
# EPOCH 20:	Training loss : 0.014	Validation loss : 0.013
#
# EPOCH 21:	Training loss : 0.013	Validation loss : 0.013
#
# EPOCH 22:	Training loss : 0.013	Validation loss : 0.012
#
# EPOCH 23:	Training loss : 0.012	Validation loss : 0.012
#
# EPOCH 24:	Training loss : 0.012	Validation loss : 0.011
#
# EPOCH 25:	Training loss : 0.011	Validation loss : 0.011
#
# EPOCH 26:	Training loss : 0.011	Validation loss : 0.011
#
# EPOCH 27:	Training loss : 0.011	Validation loss : 0.010
#
# EPOCH 28:	Training loss : 0.010	Validation loss : 0.010
#
# EPOCH 29:	Training loss : 0.010	Validation loss : 0.010
#
# EPOCH 30:	Training loss : 0.010	Validation loss : 0.009

# %%
fig, ax = plt.subplots(2, 2, figsize = (12, 10))
ax[0, 0].plot(train_losses)
ax[0, 0].set(xlabel = 'Epoch', ylabel = 'Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_losses, 'orange')
ax[0, 1].set(xlabel = 'Epoch', ylabel = 'Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_accs)
ax[1, 0].set(xlabel = 'Epoch', ylabel = 'Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_accs, 'orange')
ax[1, 1].set(xlabel = 'Epoch', ylabel = 'Accuracy')
ax[1, 1].set_title('Validation Accuracy')

plt.show()

# %% [markdown]
# ### 12. Đánh giá mô hình:

# %%
val_set_acc = compute_accuracy (X_val , y_val , theta )
test_set_acc = compute_accuracy ( X_test , y_test , theta )
print ('Evaluation on validation and test set :')
print (f'Accuracy : { val_set_acc }')
print (f'Accuracy : { test_set_acc }')
# Out:
# Evaluation on validation and test set :
# Accuracy : 0.9992977774656788
# Accuracy : 0.9992275552122467
